# %%
# My Agents Project - Experiments

This notebook provides examples and experiments for working with the agents project.

## Setup

First, let's set up the environment and import our modules.

# %%
import sys
from pathlib import Path

# Add project root to path
project_root = Path().absolute().parent
sys.path.append(str(project_root))

# Import our modules
from src.agents import ChatAgent
from src.memory import MemoryStore
from src.tools import get_basic_tools
from src.config import get_settings

print("✅ Imports successful!")

# %%
# Agent Experiments

This notebook is for experimenting with different agent configurations and testing new features.

# %%
# Setup
import sys
from pathlib import Path

# Add the parent directory to the path so we can import from src
sys.path.insert(0, str(Path.cwd().parent))

from src.agents.chat import ChatAgent
from src.utils.helpers import load_env, setup_logging

# Load environment variables and setup logging
load_env()
setup_logging("INFO")

# %%
## Basic Chat Agent Test

# %%
# Create a simple chat agent
agent = ChatAgent(memory_enabled=False)

# Test basic conversation
response = agent.run("Hello! Can you help me with a simple calculation? What's 15 * 23?")
print(response)
